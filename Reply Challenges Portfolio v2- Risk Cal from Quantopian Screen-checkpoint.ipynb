# %% [markdown]
# # Notebook Setup

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px
import quandl

# %% [markdown]
# # Equity Sub-Portfolio

# %% [markdown]
# Share Price Quote

# %%
tickers = ['SOF.BR', 'UMI.BR', 'AMT','0700.HK','2778.HK','DOCU','0823.HK']
eq_price = pd.DataFrame()
for t in tickers:
    eq_price[t] = wb.DataReader(t,data_source = 'yahoo',start = '2015-1-1')['Adj Close']
    eq_price.rename(columns={'SOF.BR': 'Sofina', 'UMI.BR':'Umicore','0700.HK':'Tencent',\
                             '2778.HK':'Champion REIT','DOCU':'Docusign','0823.HK':'Link REIT'}, inplace=True)

# %%
eq_price.tail()
# Out:
#                 Sofina    Umicore         AMT     Tencent  Champion REIT  \
# Date
# 2020-03-17  155.800003  30.440001  227.529999  349.799988           4.15
# 2020-03-18  155.000000  35.000000  217.139999  334.000000           4.11
# 2020-03-19  157.199997  33.889999  209.000000  343.000000           4.16
# 2020-03-20  164.800003  36.680000  195.389999  359.600006           4.12
# 2020-03-23  167.000000  35.580002  179.089996  348.000000           4.05
#
#              Docusign  Link REIT
# Date
# 2020-03-17  70.940002  72.949997
# 2020-03-18  76.610001  70.650002
# 2020-03-19  75.879997  66.699997
# 2020-03-20  79.699997  66.750000
# 2020-03-23  83.500000  63.750000

# %%
(eq_price / eq_price.iloc[0] * 100).plot(figsize = (15,8));
plt.show()

# %% [markdown]
# Returns Calculation

# %%
eq_returns = (eq_price/ eq_price.shift(1)) - 1
eq_returns.tail()
# Out:
#               Sofina   Umicore       AMT   Tencent  Champion REIT  Docusign  \
# Date
# 2020-03-17 -0.108696  0.022849  0.122219  0.023406       0.004843 -0.018946
# 2020-03-18 -0.005135  0.149803 -0.045664 -0.045169      -0.009639  0.079927
# 2020-03-19  0.014194 -0.031714 -0.037487  0.026946       0.012165 -0.009529
# 2020-03-20  0.048346  0.082325 -0.065120  0.048397      -0.009615  0.050343
# 2020-03-23  0.013349 -0.029989 -0.083423 -0.032258      -0.016990  0.047679
#
#             Link REIT
# Date
# 2020-03-17   0.025299
# 2020-03-18  -0.031528
# 2020-03-19  -0.055909
# 2020-03-20   0.000750
# 2020-03-23  -0.044944

# %%
annual_eq_returns = pd.DataFrame(eq_returns.mean()*250)
annual_eq_returns
# Out:
#                       0
# Sofina         0.155075
# Umicore        0.229477
# AMT            0.116958
# Tencent        0.263879
# Champion REIT  0.060918
# Docusign       0.440358
# Link REIT      0.095310

# %% [markdown]
# Risk Metrics Calculation

# %%
annual_eq_volatility = pd.DataFrame(eq_returns.std() * 250 **0.5)
annual_eq_volatility
# Out:
#                       0
# Sofina         0.175513
# Umicore        0.313715
# AMT            0.229552
# Tencent        0.288666
# Champion REIT  0.212370
# Docusign       0.499507
# Link REIT      0.194588

# %%
eq_corr_matrix = eq_returns.corr()
eq_corr_matrix
# Out:
#                  Sofina   Umicore       AMT   Tencent  Champion REIT  \
# Sofina         1.000000  0.351830  0.162703  0.277008       0.133660
# Umicore        0.351830  1.000000  0.159592  0.255217       0.125213
# AMT            0.162703  0.159592  1.000000  0.104331       0.091955
# Tencent        0.277008  0.255217  0.104331  1.000000       0.285001
# Champion REIT  0.133660  0.125213  0.091955  0.285001       1.000000
# Docusign       0.284349  0.237756  0.130288  0.159007       0.096549
# Link REIT      0.103368  0.105982  0.127603  0.288693       0.348704
#
#                Docusign  Link REIT
# Sofina         0.284349   0.103368
# Umicore        0.237756   0.105982
# AMT            0.130288   0.127603
# Tencent        0.159007   0.288693
# Champion REIT  0.096549   0.348704
# Docusign       1.000000   0.049465
# Link REIT      0.049465   1.000000

# %%
eq_heat_map = sb.heatmap(eq_corr_matrix, annot=True, cmap="YlGnBu")
plt.xlabel("Correlation Matrix of Stock Sub-Portfolio")
plt.ylabel("Ticker")
plt.show()

# %%
eq_cov_matrix_a = eq_returns.cov() *250
eq_cov_matrix_a
# Out:
#                  Sofina   Umicore       AMT   Tencent  Champion REIT  \
# Sofina         0.030805  0.019372  0.006570  0.014021       0.004977
# Umicore        0.019372  0.098417  0.011647  0.023334       0.008422
# AMT            0.006570  0.011647  0.052694  0.006998       0.004506
# Tencent        0.014021  0.023334  0.006998  0.083328       0.017472
# Champion REIT  0.004977  0.008422  0.004506  0.017472       0.045101
# Docusign       0.031266  0.047763  0.018271  0.024804       0.009542
# Link REIT      0.003527  0.006532  0.005797  0.016216       0.014410
#
#                Docusign  Link REIT
# Sofina         0.031266   0.003527
# Umicore        0.047763   0.006532
# AMT            0.018271   0.005797
# Tencent        0.024804   0.016216
# Champion REIT  0.009542   0.014410
# Docusign       0.249507   0.005256
# Link REIT      0.005256   0.037865

# %%
eq_heat_map = sb.heatmap(eq_cov_matrix_a, annot=True, cmap="YlGnBu")
plt.xlabel("Covariance Matrix of Stock Sub-Portfolio")
plt.ylabel("Ticker")
plt.show()

# %% [markdown]
# Benchmark Quote

# %%
tickers = ['^GSPC','^GDAXI','^FCHI']
eq_indx_data = pd.DataFrame()
for t in tickers:
    eq_indx_data[t] = wb.DataReader(t, data_source='yahoo', start = '2015-1-1')['Adj Close']
    eq_indx_data.rename(columns={'^GSPC': 'S&P 500', '^GDAXI':'DAX','^FCHI':'CAC 40'}, inplace=True)

# %%
eq_indx_data.head()
# Out:
#                 S&P 500          DAX       CAC 40
# Date
# 2015-01-02  2058.199951  9764.730469  4252.290039
# 2015-01-05  2020.579956  9473.160156  4111.359863
# 2015-01-06  2002.609985  9469.660156  4083.500000
# 2015-01-07  2025.900024  9518.179688  4112.729980
# 2015-01-08  2062.139893  9837.610352  4260.189941

# %%
(eq_indx_data / eq_indx_data.iloc[0] * 100).plot(figsize = (15,8));
plt.show()

# %%
eq_indx_returns = (eq_indx_data/ eq_indx_data.shift(1)) - 1
eq_indx_returns.head()
# Out:
#              S&P 500       DAX    CAC 40
# Date
# 2015-01-02       NaN       NaN       NaN
# 2015-01-05 -0.018278 -0.029860 -0.033142
# 2015-01-06 -0.008893 -0.000369 -0.006776
# 2015-01-07  0.011630  0.005124  0.007158
# 2015-01-08  0.017888  0.033560  0.035855

# %%
avg_indx_returns = pd.DataFrame(eq_indx_returns.mean() *250)
avg_indx_returns
# Out:
#                 0
# S&P 500  0.030734
# DAX     -0.005328
# CAC 40   0.006922

# %% [markdown]
# Equity Sub-portfolio Allocation

# %%
# Calculate equal risk weights based on the number of stocks chosen in the portfolio 
numstocks = len(eq_price.columns)
print(numstocks)

eq_risk_weights = np.repeat(1/numstocks, numstocks)
eq_risk_weights
# Out:
# 7
# array([0.14285714, 0.14285714, 0.14285714, 0.14285714, 0.14285714,
#        0.14285714, 0.14285714])

# %%
# Define Target Volatility
target_volatility=0.1

# Calculate the Volatility Ratio which is (Target Volatility/ Stock Volatility)
eq_volatility_ratio = pd.DataFrame(target_volatility/annual_eq_volatility)
eq_volatility_ratio
# Out:
#                       0
# Sofina         0.569759
# Umicore        0.318760
# AMT            0.435631
# Tencent        0.346421
# Champion REIT  0.470876
# Docusign       0.200197
# Link REIT      0.513906

# %%
# Calculate the Initial Cash Weights which is (Risk Weights * Equity Volatility Ratio)
eq_cash_weights = pd.DataFrame(eq_risk_weights* eq_volatility_ratio[0])
eq_cash_weights
# Out:
#                       0
# Sofina         0.081394
# Umicore        0.045537
# AMT            0.062233
# Tencent        0.049489
# Champion REIT  0.067268
# Docusign       0.028600
# Link REIT      0.073415

# %%
# Calculate the Normalizing Factor 
eq_normalizing_factor = np.repeat(1/eq_cash_weights.sum(),1)
eq_normalizing_factor
# Out:
# 0    2.451367
# dtype: float64

# %%
# Multiply the Initial Cash Weights with the Normalizing Factor to make sure the portfolio sums up to 1
eq_final_cash_weights = eq_cash_weights * eq_normalizing_factor
eq_final_cash_weights
# Out:
#                       0
# Sofina         0.199527
# Umicore        0.111628
# AMT            0.152556
# Tencent        0.121315
# Champion REIT  0.164899
# Docusign       0.070108
# Link REIT      0.179967

# %%
# Check if the whole portfolio sums up to 1, by rounding the calculated sum to 9 digits
round(eq_final_cash_weights.sum(),9)==1
# Out:
# 0    True
# dtype: bool

# %%
# Summary Table of how different types of cash weights are derived
eq_allocation_table = pd.DataFrame({'Initial Cash Weights':eq_cash_weights[0], 'Normalizing Factor':eq_normalizing_factor[0]\
                                  , 'Final Cash Weights':eq_cash_weights[0] * eq_normalizing_factor[0]})
eq_allocation_table
# Out:
#                Initial Cash Weights  Normalizing Factor  Final Cash Weights
# Sofina                     0.081394            2.451367            0.199527
# Umicore                    0.045537            2.451367            0.111628
# AMT                        0.062233            2.451367            0.152556
# Tencent                    0.049489            2.451367            0.121315
# Champion REIT              0.067268            2.451367            0.164899
# Docusign                   0.028600            2.451367            0.070108
# Link REIT                  0.073415            2.451367            0.179967

# %%
# Create Pie chart for Final Cash Weights
plt.figure(figsize=(5,5))

labels = [eq_price.columns[0],eq_price.columns[1],eq_price.columns[2],eq_price.columns[3],eq_price.columns[4],\
          eq_price.columns[5],eq_price.columns[6]]
values = [eq_final_cash_weights[0]]
explode = [0,0,0,0,0,0,0]

plt.pie(values, labels=labels, autopct="%.1f%%", explode=explode)

plt.show()
# Out:
# C:\Users\chris\anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
#
# Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
# Calculate the Expected Portfolio Return for individual equities
eq_E_R = pd.DataFrame(eq_final_cash_weights[0] * annual_eq_returns[0])
eq_E_R
# Out:
#                       0
# Sofina         0.030942
# Umicore        0.025616
# AMT            0.017843
# Tencent        0.032012
# Champion REIT  0.010045
# Docusign       0.030873
# Link REIT      0.017153

# %% [markdown]
# Performance Evaluation

# %%
eq_bench_port = pd.DataFrame({'E (Eq Return)':eq_E_R.sum(), 'S&P 500':avg_indx_returns.T['S&P 500'], \
                              'DAX':avg_indx_returns.T['DAX'], 'CAC':avg_indx_returns.T['CAC 40'] })
eq_bench_port.rename(index={0:'Annual Return'}, inplace = True)
eq_bench_port
# Out:
#                E (Eq Return)   S&P 500       DAX       CAC
# Annual Return       0.164484  0.030734 -0.005328  0.006922

# %%
delta = pd.DataFrame({'E (Eq Return)':eq_bench_port['E (Eq Return)']-eq_bench_port['E (Eq Return)'],\
                      'S&P 500':eq_bench_port['E (Eq Return)']-eq_bench_port['S&P 500'], \
                     'DAX':eq_bench_port['E (Eq Return)']-eq_bench_port['DAX'], \
                      'CAC':eq_bench_port['E (Eq Return)']-eq_bench_port['CAC']})

eq_bench_port_append = eq_bench_port.append(delta,ignore_index = True)
eq_bench_port_append.rename(index={0:'Annual Return', 1:'Delta Benchmark'}, inplace = True)
eq_bench_port_append
# Out:
#                  E (Eq Return)   S&P 500       DAX       CAC
# Annual Return         0.164484  0.030734 -0.005328  0.006922
# Delta Benchmark       0.000000  0.133750  0.169812  0.157561

# %% [markdown]
# ## Fixed Income Sub-Portfolio

# %% [markdown]
# Bond Price Quote

# %%
US_t_yield = quandl.get("USTREASURY/YIELD",start_date='2020-2-15')['10 YR']
US_t_yield.head(30)
# Out:
# Date
# 2020-02-18    1.55
# 2020-02-19    1.56
# 2020-02-20    1.52
# 2020-02-21    1.46
# 2020-02-24    1.38
# 2020-02-25    1.33
# 2020-02-26    1.33
# 2020-02-27    1.30
# 2020-02-28    1.13
# 2020-03-02    1.10
# 2020-03-03    1.02
# 2020-03-04    1.02
# 2020-03-05    0.92
# 2020-03-06    0.74
# 2020-03-09    0.54
# 2020-03-10    0.76
# 2020-03-11    0.82
# 2020-03-12    0.88
# 2020-03-13    0.94
# 2020-03-16    0.73
# 2020-03-17    1.02
# 2020-03-18    1.18
# 2020-03-19    1.12
# 2020-03-20    0.92
# 2020-03-23    0.76
# 2020-03-24    0.84
# Name: 10 YR, dtype: float64

# %%
EM_corpbond = quandl.get("ML/EMHYY",start_date='2020-2-15')
EM_corpbond.head(30)
# Out:
#             BAMLEMHBHYCRPIEY
# DATE
# 2020-02-17              6.05
# 2020-02-18              6.01
# 2020-02-19              6.01
# 2020-02-20              5.98
# 2020-02-21              5.98
# 2020-02-24              6.09
# 2020-02-25              6.12
# 2020-02-26              6.25
# 2020-02-27              6.45
# 2020-02-28              6.67
# 2020-02-29              6.70
# 2020-03-02              6.73
# 2020-03-03              6.57
# 2020-03-04              6.48
# 2020-03-05              6.53
# 2020-03-06              6.71
# 2020-03-09              7.59
# 2020-03-10              7.67
# 2020-03-11              7.94
# 2020-03-12              8.78
# 2020-03-13              9.14
# 2020-03-16              9.95
# 2020-03-17             10.51
# 2020-03-18             11.75
# 2020-03-19             12.76
# 2020-03-20             12.98
# 2020-03-23             13.55

# %%
US_AAA = quandl.get("ML/AAAEY",start_date='2020-3-15')
US_AAA.head()
# Out:
#             BAMLC0A1CAAAEY
# DATE
# 2020-03-16            2.28
# 2020-03-17            2.58
# 2020-03-18            2.96
# 2020-03-19            3.10
# 2020-03-20            3.36
